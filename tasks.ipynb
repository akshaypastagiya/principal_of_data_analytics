# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1: Source the Data Set

# %% [markdown]
# ### Import Iris data from
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html
#
# ### Use Pands Library to explore Iris Dataset
#
# https://pandas.pydata.org/docs/user_guide/index.html#user-guide
#
# ### Use Matplot library to plt the different type of graphis
#
# https://matplotlib.org/stable/users/index.html

# %%
# Impoer sklearn Library to import the iris dataset

import sklearn as skl;

# Import the pandas library to read the iris dataset

import pandas as pd;

# Plots.
import matplotlib.pyplot as plt

# Numerical arrays.
import numpy as np

# %%
# Import the iris dataset
# load_iris() is a function in the datasets module of the sklearn library which will load the iris dataset

iris = skl.datasets.load_iris();

# %% [markdown]
# ## Task2 : Explore the data Stracture

# %%
#Create a dataframe of the iris dataset
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names);

# Add the target column to the dataframe
iris_df['target'] = iris.target

# %%
# Print the shape of the dataset

print("Shape of the dataset:", iris_df.shape)
# Out:
# Shape of the dataset: (150, 5)

# %%
# Print the first 5 rows of the dataset

print("First 5 rows of the dataset:", iris_df.head())
# Out:
# First 5 rows of the dataset:    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#Print the last 5 rows of the dataset
print("Last 5 rows of the dataset:", iris_df.tail())
# Out:
# Last 5 rows of the dataset:      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
#Print the features of the dataset
print("Features of the dataset:", iris.feature_names)
# Out:
# Features of the dataset: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
#Print the target class of the dataset
print("Target class of the dataset:", iris.target_names)
# Out:
# Target class of the dataset: ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# # Task 3: Summarize the Data

# %%
#calculate mean of dataset
print("Mean of the dataset:", iris_df.mean())
# Out:
# Mean of the dataset: sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# target               1.000000
# dtype: float64

# %%
#calculate the minimum value of the dataset
print("Minimum value of the dataset:", iris_df.min())
# Out:
# Minimum value of the dataset: sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# target               0.0
# dtype: float64

# %%
#print the maximum value of the dataset 
print("Maximum value of the dataset:", iris_df.max())
# Out:
# Maximum value of the dataset: sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# target               2.0
# dtype: float64

# %%
#print the standard deviation of the dataset
print("Standard deviation of the dataset:", iris_df.std())
# Out:
# Standard deviation of the dataset: sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# target               0.819232
# dtype: float64

# %%
#print the median of the dataset
print("Median of the dataset:", iris_df.median())
# Out:
# Median of the dataset: sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# target               1.00
# dtype: float64

# %%
# Transfer sepal length to a numpy array

sepal_length = iris_df['sepal length (cm)'].values

# Transfer sepal width to a numpy array

sepal_width = iris_df['sepal width (cm)'].values

# Transfer petal length to a numpy array

petal_length = iris_df['petal length (cm)'].values

# Transfer petal width to a numpy array

petal_width = iris_df['petal width (cm)'].values

# Transfer target to a numpy array

target = iris_df['target'].values

# %% [markdown]
# ### Use matplot lib to plot the relation graph

# %%
# Plot graph between sepal length vs sepal width
plt.plot(sepal_length, sepal_width, '.', label='sepal length vs sepal width')

#Add legent to the graph
plt.legend()

# Add title to the graph
plt.title('Sepal length and width')

# Add labels to the graph
plt.xlabel('Sepal length')
plt.ylabel('Sepal width');

# %%
# Plot graph between petal length vs petal width
plt.plot(petal_length, petal_width, '.', label='petal length vs petal width')

#Add legent to the graph
plt.legend()

# Add title to the graph
plt.title('Petal length and width')

# Add labels to the graph
plt.xlabel('Petal length')
plt.ylabel('Petal width');

# %%
# Plot graph between sepal length vs petal length
plt.plot(sepal_length, petal_length, '.', label='sepal length vs petal length')

#Add legent to the graph
plt.legend()

# Add title to the graph
plt.title('Length of Sepal and Petal')

# Add labels to the graph
plt.xlabel('Sepal length')
plt.ylabel('Petal length');

# %%
# Plot graph between sepal width vs petal width
plt.plot(sepal_width, petal_width, '.', label='sepal width vs petal width')

#Add legent to the graph
plt.legend()  

# Add title to the graph
plt.title('Width of Sepal and Petal')

# Add labels to the graph
plt.xlabel('Sepal width')
plt.ylabel('Petal width');

# %%
#Compare the sepal length and width of the iris dataset
plt.plot(sepal_length, sepal_width,".",label = 'sepal')
plt.plot(petal_length, petal_width,".",label = 'petal')

# Add legend to the graph
plt.legend()

# Add title to the graph
plt.title('Sepal and Petal comparison')

# Add labels to the graph
plt.xlabel('length')
plt.ylabel('width');

# %%
# Compare the length and width of the sepal and petal of the iris dataset
plt.plot(sepal_length, petal_length,".",label = 'length')
plt.plot(sepal_width, petal_width,".",label = 'width')

# Add legend to the graph
plt.legend()

# Add title to the graph
plt.title('Length and Width comparison')

# Add labels to the graph
plt.xlabel('sepal')
plt.ylabel('petal');

# %% [markdown]
# ## Task 4: Visualize Features

# %% [markdown]
# ### Plot histograms for each feature using matplotlib.
#
# https://matplotlib.org/stable/gallery/statistics/hist.html
#
# https://matplotlib.org/stable/gallery/statistics/hist.html#sphx-glr-gallery-statistics-hist-py

# %%
# Plto Histogram of the sepal length, sepal width, petal length and petal width

plt.figure()
plt.subplot()
plt.hist(sepal_length)
#plt.title('Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')

plt.subplot()
plt.hist(sepal_width)
#plt.title('Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')

plt.subplot()
plt.hist(petal_length)
#plt.title('Petal Length')
plt.xlabel('Petal Length')
plt.ylabel('Frequency')

plt.subplot()
plt.hist(petal_width)
#plt.title('Petal Width')
plt.xlabel('Petal Width')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Plot 2D histogram of the sepal length and sepal width
plt.figure()
plt.subplot()
plt.hist2d(sepal_length, sepal_width, bins=20)


# Plot 2D histogram of the petal length and petal width
plt.colorbar()
plt.subplot()
plt.hist2d(petal_length, petal_width, bins=20)
# Add labels to the graph
plt.xlabel('length')
plt.ylabel('width')
# Add title to the graph
plt.title('2D histogram of petal / sepal length and width')
# Out:
# Text(0.5, 1.0, '2D histogram of petal / sepal length and width')

# %% [markdown]
# ## Task 5: Investigate Relationships
# ### Choose any two features from the data set and create a scatter plot of them.
# ### Color-code the three different classes of the scatter plot points.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
# plot scatter plot of the sepal length and sepal width
plt.figure()
plt.subplot()
plt.scatter(sepal_length, sepal_width)
# Add labels to the graph
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# Add title to the graph
plt.title('Scatter plot of sepal length and width')
# Out:
# Text(0.5, 1.0, 'Scatter plot of sepal length and width')

# %%
#scatter plot of the petal length and petal width
plt.figure()
plt.subplot()
plt.scatter(petal_length, petal_width)
# Add labels to the graph
plt.xlabel('Petal length')
plt.ylabel('Petal width')
# Add title to the graph
plt.title('Scatter plot of petal length and width')
# Out:
# Text(0.5, 1.0, 'Scatter plot of petal length and width')

# %% [markdown]
# ## Task 6: Analyze Relationship
# ### To analyze the relationship will be using NumPy Polyfit
# ### https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html

# %%
# Fit a line with polyfit for seplal length and sepal width
slop,intercept = np.polyfit(sepal_length, sepal_width, 1)

print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Out:
# Slope of the line: -0.06188479796414418
# Intercept of the line: 3.4189468361038142

# %%
#scatter plot of the sepal length and sepal width
plt.figure()
plt.scatter(sepal_length, sepal_width)
# Add labels to the graph
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# Add title to the graph
plt.title('Scatter plot of sepal length and width')
# Add the line to the graph
plt.plot(sepal_length, slop*sepal_length + intercept, color='red')
plt.legend(['sepal length vs sepal width', 'line'])
plt.show()

# %%
# Fit a line with polyfit for petal length and petal width
slop,intercept = np.polyfit(petal_length, petal_width, 1)

print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Out:
# Slope of the line: 0.41575541635241153
# Intercept of the line: -0.36307552131902887

# %%
#scatter plot of the petal length and petal width
plt.figure()
plt.scatter(petal_length, petal_width)
# Add labels to the graph
plt.xlabel('Petal length')
plt.ylabel('Petal width')
# Add title to the graph
plt.title('Scatter plot of petal length and width')
# Add the line to the graph
plt.plot(petal_length, slop*petal_length + intercept, color='red')
plt.legend(['petal length vs petal width', 'line'])
plt.show()

# %%
# Fit a line with polyfit for sepal length and petal length
slop,intercept = np.polyfit(sepal_length, petal_length, 1)
print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Out:
# Slope of the line: 1.858432978254841
# Intercept of the line: -7.1014433696024515

# %%
#scatter plot of the sepal length and petal length
plt.figure()
plt.scatter(sepal_length, petal_length)
# Add labels to the graph
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
# Add title to the graph
plt.title('Scatter plot of sepal length and petal length')
# Add the line to the graph
plt.plot(sepal_length, slop*sepal_length + intercept, color='red')
plt.legend(['sepal length vs petal length', 'line'])
plt.show()

# %%
# Fit a line with polyfit for sepal width and petal width
slop,intercept = np.polyfit(sepal_width, petal_width, 1)
print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Out:
# Slope of the line: -0.6402765871258863
# Intercept of the line: 3.1568722857062097

# %%
#scatter plot of the sepal width and petal width
plt.figure()
plt.scatter(sepal_width, petal_width)
# Add labels to the graph
plt.xlabel('Sepal width')
plt.ylabel('Petal width')
# Add title to the graph
plt.title('Scatter plot of sepal width and petal width')
# Add the line to the graph
plt.plot(sepal_width, slop*sepal_width + intercept, color='red')
plt.legend(['sepal width vs petal width', 'line'])
plt.show()

# %% [markdown]
# ## Task 7: Analyze Class Distributions
# ### Create box-plots of petal and sepal length grouped by class
# ### https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html#matplotlib.pyplot.boxplot

# %%
# get three classes of the iris dataset

iris_setosa = iris_df[iris_df['target'] == 0]
iris_versicolor = iris_df[iris_df['target'] == 1]
iris_virginica = iris_df[iris_df['target'] == 2]

# %%
# Create a box plot of the sepal length with respect to the three classes of the iris dataset
plt.figure()
plt.subplot()
plt.boxplot([iris_setosa['sepal length (cm)'], iris_versicolor['sepal length (cm)'], iris_virginica['sepal length (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Add labels to the graph
plt.xlabel('Iris species')
plt.ylabel('Sepal length (cm)')
# Add title to the graph
plt.title('Box plot of sepal length with respect to the three classes of the iris dataset')
# Out:
# /tmp/ipykernel_14699/2177446700.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([iris_setosa['sepal length (cm)'], iris_versicolor['sepal length (cm)'], iris_virginica['sepal length (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Text(0.5, 1.0, 'Box plot of sepal length with respect to the three classes of the iris dataset')

# %%
# Create a box plot of the sepal width with respect to the three classes of the iris dataset
plt.figure()
plt.subplot()
plt.boxplot([iris_setosa['sepal width (cm)'], iris_versicolor['sepal width (cm)'], iris_virginica['sepal width (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Add labels to the graph
plt.xlabel('Iris species')
plt.ylabel('Sepal width (cm)')
# Add title to the graph
plt.title('Box plot of sepal width with respect to the three classes of the iris dataset')
# Out:
# /tmp/ipykernel_14699/446878964.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([iris_setosa['sepal width (cm)'], iris_versicolor['sepal width (cm)'], iris_virginica['sepal width (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Text(0.5, 1.0, 'Box plot of sepal width with respect to the three classes of the iris dataset')

# %%
# create a box plot of the petal length with respect to the three classes of the iris dataset
plt.figure()
plt.subplot()
plt.boxplot([iris_setosa['petal length (cm)'], iris_versicolor['petal length (cm)'], iris_virginica['petal length (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Add labels to the graph
plt.xlabel('Iris species')
plt.ylabel('Petal length (cm)')
# Add title to the graph
plt.title('Box plot of petal length with respect to the three classes of the iris dataset')
# Out:
# /tmp/ipykernel_14699/260409336.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([iris_setosa['petal length (cm)'], iris_versicolor['petal length (cm)'], iris_virginica['petal length (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Text(0.5, 1.0, 'Box plot of petal length with respect to the three classes of the iris dataset')

# %%
# create a box plot of the petal width with respect to the three classes of the iris dataset
plt.figure()
plt.subplot()
plt.boxplot([iris_setosa['petal width (cm)'], iris_versicolor['petal width (cm)'], iris_virginica['petal width (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Add labels to the graph
plt.xlabel('Iris species')
plt.ylabel('Petal width (cm)')
# Add title to the graph
plt.title('Box plot of petal width with respect to the three classes of the iris dataset')ot
# Out:
# /tmp/ipykernel_14699/2797352830.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([iris_setosa['petal width (cm)'], iris_versicolor['petal width (cm)'], iris_virginica['petal width (cm)']], labels=['setosa', 'versicolor', 'virginica'])
# Text(0.5, 1.0, 'Box plot of petal width with respect to the three classes of the iris dataset')

# %% [markdown]
# ## Task 8: Compute Correlations
# ### calculate the correlation coefficients between features using numpy.corrcoef()
# ### https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html

# %%
# Calculate the correlation matrix of the iris dataset
correlation_matrix = iris_df.corr()
# Print the correlation matrix
print("Correlation matrix of the iris dataset:", correlation_matrix)
# Out:
# Correlation matrix of the iris dataset:                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %% [markdown]
# ## Task 9: Fit a Simple Linear Regression
# ### Calculate the simple Linear Regression using numpy.polyfit()
# ### Calculate the R^2 coefficient of determination

# %% [markdown]
# #### R^2 Mathmical Equation as below
# The equation provided in the code calculates the **coefficient of determination** ($R^2$), which is a statistical measure of how well the regression line approximates the data points. Mathematically, the formula for $R^2$ in this context is:
#
# ### **Mathematical Equation**
# $$
# R^2 = 1 - \frac{\text{SS}_{\text{residual}}}{\text{SS}_{\text{total}}}
# $$
#
# Where:
# - $\text{SS}_{\text{residual}}$ is the **residual sum of squares**, representing the variability of the data around the regression line:
#   $$
#   \text{SS}_{\text{residual}} = \sum_{i} \left( y_i - \hat{y}_i \right)^2
#   $$
#   In the code:
#   $$
#   \text{SS}_{\text{residual}} = \sum \left( \text{petal\_length} - (\text{slope} \cdot \text{sepal\_length} + \text{intercept}) \right)^2
#   $$
#
# - $\text{SS}_{\text{total}}$ is the **total sum of squares**, representing the variability of the data around its mean:
#   $$
#   \text{SS}_{\text{total}} = \sum_{i} \left( y_i - \bar{y} \right)^2
#   $$
#   In the code:
#   $$
#   \text{SS}_{\text{total}} = \sum \left( \text{petal\_length} - \text{mean}(\text{petal\_length}) \right)^2
#   $$
#
# Hence, the formula for $R^2$ in the code evaluates:
# $$
# R^2 = 1 - \frac{\sum \left( \text{petal\_length} - (\text{slope} \cdot \text{sepal\_length} + \text{intercept}) \right)^2}{\sum \left( \text{petal\_length} - \text{mean}(\text{petal\_length}) \right)^2}
# $$
#
# ---
#
# ### **Explanation of Terms**
# 1. **$y_i$**:
#    - Represents the actual data value (e.g., `petal_length`).
#
# 2. **$\hat{y}_i$**:
#    - Represents the predicted value from the regression model, calculated as:
#      $$
#      \hat{y}_i = (\text{slope} \cdot \text{sepal\_length}) + \text{intercept}
#      $$
#
# 3. **Residual Variability** ($\text{SS}_{\text{residual}}$):
#    - Measures how far the actual values deviate from the predicted values.
#
# 4. **Total Variability** ($\text{SS}_{\text{total}}$):
#    - Measures how far the actual values deviate from the mean of the dataset.
#
# 5. **Interpretation of $R^2$**:
#    - $R^2$ quantifies the proportion of variance in the dependent variable (e.g., `petal_length`) that is explained by the independent variable (e.g., `sepal_length`) using the regression model.
#
# ---
#
# With $R^2$ close to **1**, the regression line explains most of the variance in the data, indicating a strong relationship. If $R^2$ approaches **0**, the relationship is weak. Would you like further clarification or visualization of this equation? 😊
#
# *This is an AI generated response.

# %%
# calculation of simple linear regression and calculation of the R^2 value using numpy.polyfit
# Fit a line with polyfit for sepal length and sepal width
slop,intercept = np.polyfit(sepal_length, sepal_width, 1)
print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Calculate the R^2 value
ss_total = np.sum((sepal_width - np.mean(sepal_width))**2)
ss_residual = np.sum((sepal_width - (slop*sepal_length + intercept))**2)
r_squared = 1 - (ss_residual / ss_total)
print("R^2 value:", r_squared)
# Fit a line with polyfit for petal length and petal width
slop,intercept = np.polyfit(petal_length, petal_width, 1)
print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Calculate the R^2 value
ss_total = np.sum((petal_width - np.mean(petal_width))**2)
ss_residual = np.sum((petal_width - (slop*petal_length + intercept))**2)
r_squared = 1 - (ss_residual / ss_total)
print("R^2 value:", r_squared)
# Fit a line with polyfit for sepal length and petal length
slop,intercept = np.polyfit(sepal_length, petal_length, 1)
print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Calculate the R^2 value
ss_total = np.sum((petal_length - np.mean(petal_length))**2)
ss_residual = np.sum((petal_length - (slop*sepal_length + intercept))**2)
r_squared = 1 - (ss_residual / ss_total)
print("R^2 value:", r_squared)
# Fit a line with polyfit for sepal width and petal width
slop,intercept = np.polyfit(sepal_width, petal_width, 1)
print("Slope of the line:", slop)
print("Intercept of the line:", intercept)
# Calculate the R^2 value
ss_total = np.sum((petal_width - np.mean(petal_width))**2)
ss_residual = np.sum((petal_width - (slop*sepal_width + intercept))**2)
r_squared = 1 - (ss_residual / ss_total)
print("R^2 value:", r_squared)
# Out:
# Slope of the line: -0.06188479796414418
# Intercept of the line: 3.4189468361038142
# R^2 value: 0.013822654141080748
# Slope of the line: 0.41575541635241153
# Intercept of the line: -0.36307552131902887
# R^2 value: 0.9271098389904927
# Slope of the line: 1.858432978254841
# Intercept of the line: -7.1014433696024515
# R^2 value: 0.7599546457725151
# Slope of the line: -0.6402765871258863
# Intercept of the line: 3.1568722857062097
# R^2 value: 0.13404819847567684

# %% [markdown]
# ## Task 10: Too Many Features
# ### Use seaborn to create a pairplot of the data set.
# ### Explain, in your own words, what the pairplot depicts.
# ### https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
import seaborn as sns
# Create a pair plot of the iris dataset
sns.pairplot(iris_df, hue='target', palette='husl')
plt.show()

# %% [markdown]
# ### Explanation:
# #### - Pairplot displays plots for feature combinations and histograms for individual features and illustrating the clustering of Iris species in the feature space.

# %% [markdown]
# ## End
